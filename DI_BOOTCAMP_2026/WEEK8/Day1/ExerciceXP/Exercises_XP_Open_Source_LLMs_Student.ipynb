# %% [markdown]
# # Exercises XP: Open-Source LLM Strategy (Student)
# Use this guided notebook and fill each TODO. Run it in Colab if you prefer; GPU not required unless you try optional model runs.

# %% [markdown]
# ## What you'll learn
# - Identify degrees of openness in LLMs and what each enables.
# - Understand and compare open-source licenses.
# - Assess strengths/trade-offs of open LLMs for specific constraints (CPU, math, multilingual).
# - Evaluate which models fit given hardware and licensing needs.
# - Use open tools/leaderboards to guide model selection.
# - Plan deployment trade-offs (local vs. cloud).

# %% [markdown]
# ## What you will create
# - Comparative LLM openness analysis (table + paragraph + healthcare prompt answer).
# - Licensing compatibility checklist for SaaS products.
# - Quiz-style reflection on LLM selection.
# - Local deployment readiness checklist + upgrade notes.
# - Benchmark-based model match guide.
# - Hardware upgrade plan / cost-benefit comparison (local vs. cloud).

# %% [markdown]
# ## Exercise 1: Open Source Levels Reflection
# **Use:** Fully Open, Weights Released, Architecture Only; model components; fine-tuning/domain adaptation; healthcare compliance.
#
# **Step-by-step**
# 1) Gather definitions for the three openness levels.
# 2) Identify key characteristics (what is open; what you can/cannot do).
# 3) Compare side by side in a table (what's open vs. impact).
# 4) Write a 3?5 sentence comparative paragraph.
# 5) Answer the healthcare prompt (1?2 sentences) about retraining on clinical data.
#
# **Deliverables:** paragraph + healthcare answer.

# %%
open_source_levels = {
    "Fully Open": {
        "definition": "Toutes les composantes (code, poids, données d'entraînement, architecture) sont publiquement disponibles et peuvent être utilisées, modifiées et distribuées sans restrictions significatives.",
        "what_is_open": ["Code d'entraînement", "Poids du modèle", "Architecture", "Données d'entraînement"],
        "what_you_can_do": ["Réentraîner le modèle", "Affiner (fine-tune)", "Modifier l'architecture", "Utiliser à des fins commerciales", "Auditer pour les biais/la sécurité"],
        "what_you_cannot_do": ["Très peu de restrictions, potentiellement des directives d'utilisation éthique ou des exigences d'attribution selon la licence spécifique.", ""],
    },
    "Weights Released": {
        "definition": "Les poids du modèle sont publiquement disponibles, mais le code d'entraînement ou les données peuvent ne pas l'être. L'architecture est généralement connue.",
        "what_is_open": ["Poids du modèle", "Architecture"],
        "what_you_can_do": ["Affiner (fine-tune) le modèle", "Exécuter l'inférence", "Intégrer dans des applications"],
        "what_you_cannot_do": ["Comprendre l'ensemble du processus d'entraînement", "Reproduire le modèle à partir de zéro", "Modifier en profondeur l'architecture de base"],
    },
    "Architecture Only": {
        "definition": "Seule l'architecture du modèle (par exemple, article de recherche, structure de code) est publique ; les poids et les données d'entraînement ne le sont pas.",
        "what_is_open": ["Architecture du modèle", "Articles de recherche"],
        "what_you_can_do": ["Comprendre la base théorique", "Implémenter votre propre modèle à partir de zéro", "Contribuer à la recherche"],
        "what_you_cannot_do": ["Exécuter l'inférence directement", "Affiner (fine-tune) un modèle pré-entraîné", "Utiliser des capacités pré-entraînées"],
    },
}
open_source_levels
# Out:
# {'Fully Open': {'definition': "Toutes les composantes (code, poids, données d'entraînement, architecture) sont publiquement disponibles et peuvent être utilisées, modifiées et distribuées sans restrictions significatives.",
#   'what_is_open': ["Code d'entraînement",
#    'Poids du modèle',
#    'Architecture',
#    "Données d'entraînement"],
#   'what_you_can_do': ['Réentraîner le modèle',
#    'Affiner (fine-tune)',
#    "Modifier l'architecture",
#    'Utiliser à des fins commerciales',
#    'Auditer pour les biais/la sécurité'],
#   'what_you_cannot_do': ["Très peu de restrictions, potentiellement des directives d'utilisation éthique ou des exigences d'attribution selon la licence spécifique.",
#    '']},
#  'Weights Released': {'definition': "Les poids du modèle sont publiquement disponibles, mais le code d'entraînement ou les données peuvent ne pas l'être. L'architecture est généralement connue.",
#   'what_is_open': ['Poids du modèle', 'Architecture'],
# ...

# %%
comparison_table = """| Openness level | What's open? | Impact on retraining/modifying |
| --- | --- | --- |
| Fully Open | Code, poids, architecture, données | Contrôle total, personnalisation profonde, audit de conformité facile. |
| Weights Released | Poids, architecture | Affinage possible, mais reproduction complète ou audit de la chaîne d'approvisionnement difficile. |
| Architecture Only | Architecture | Nécessite un entraînement complet, très coûteux et complexe ; aucune capacité pré-entraînée. |"""
print(comparison_table)
# Out:
# | Openness level | What's open? | Impact on retraining/modifying |
# | --- | --- | --- |
# | Fully Open | Code, poids, architecture, données | Contrôle total, personnalisation profonde, audit de conformité facile. |
# | Weights Released | Poids, architecture | Affinage possible, mais reproduction complète ou audit de la chaîne d'approvisionnement difficile. |
# | Architecture Only | Architecture | Nécessite un entraînement complet, très coûteux et complexe ; aucune capacité pré-entraînée. |

# %%
comparative_paragraph = """Les LLM "Fully Open" offrent une transparence et une flexibilité maximales, permettant une personnalisation complète et un audit. Les modèles "Weights Released" permettent l'affinage et l'inférence mais limitent la compréhension du processus d'entraînement. Enfin, les modèles "Architecture Only" ne fournissent que le plan, exigeant un entraînement coûteux et intensif en ressources, sans avantages immédiats liés aux poids pré-entraînés. Chaque niveau offre un compromis entre le contrôle, les coûts et la facilité d'utilisation, influençant profondément le développement et le déploiement.
"""
print(comparative_paragraph)
# Out:
# Les LLM "Fully Open" offrent une transparence et une flexibilité maximales, permettant une personnalisation complète et un audit. Les modèles "Weights Released" permettent l'affinage et l'inférence mais limitent la compréhension du processus d'entraînement. Enfin, les modèles "Architecture Only" ne fournissent que le plan, exigeant un entraînement coûteux et intensif en ressources, sans avantages immédiats liés aux poids pré-entraînés. Chaque niveau offre un compromis entre le contrôle, les coûts et la facilité d'utilisation, influençant profondément le développement et le déploiement.

# %%
healthcare_prompt_answer = """Pour la conformité des soins de santé et le réentraînement avec des données cliniques sensibles, un modèle "Fully Open" est idéal en raison de son contrôle total et de sa transparence. Un modèle "Weights Released" pourrait être envisagé pour l'affinage, mais exigerait une diligence raisonnable approfondie sur la lignée des données d'entraînement et les licences, car la transparence est partielle.
"""
print(healthcare_prompt_answer)
# Out:
# Pour la conformité des soins de santé et le réentraînement avec des données cliniques sensibles, un modèle "Fully Open" est idéal en raison de son contrôle total et de sa transparence. Un modèle "Weights Released" pourrait être envisagé pour l'affinage, mais exigerait une diligence raisonnable approfondie sur la lignée des données d'entraînement et les licences, car la transparence est partielle.

# %% [markdown]
# ## Exercise 2: License Check for SaaS Use
# **Use:** HF model pages; permissive vs. copyleft; commercial clauses; restrictions (MAU caps, attribution, export controls).
#
# **Step-by-step**
# 1) Select two HF models (e.g., Mistral-7B-Instruct, Llama-2-7b-chat-hf) and note URLs.
# 2) Locate the License field and copy the name.
# 3) Determine if commercial use is allowed/restricted/prohibited; note conditions.
# 4) Identify extra restrictions (MAU caps, attribution, export/geography).
# 5) Build the markdown checklist with your findings.
#
# **Deliverables:** model names + URLs + completed checklist.

# %%
license_checklist = [
    {
        "model": "mistralai/Mistral-7B-Instruct-v0.3",
        "url": "https://huggingface.co/mistralai/Mistral-7B-Instruct-v0.3",
        "license": "Apache 2.0",
        "commercial_use": "Yes",
        "restrictions": ["Attribution (via la licence Apache 2.0)", ""],
    },
    {
        "model": "meta-llama/Llama-2-7b-chat-hf",
        "url": "https://huggingface.co/meta-llama/Llama-2-7b-chat-hf",
        "license": "Llama 2 Community License",
        "commercial_use": "Conditional",
        "restrictions": ["MAU cap (moins de 700M utilisateurs actifs mensuels)", "Attribution et application de la politique d'utilisation responsable"],
    },
]
license_checklist
# Out:
# [{'model': 'mistralai/Mistral-7B-Instruct-v0.3',
#   'url': 'https://huggingface.co/mistralai/Mistral-7B-Instruct-v0.3',
#   'license': 'Apache 2.0',
#   'commercial_use': 'Yes',
#   'restrictions': ['Attribution (via la licence Apache 2.0)', '']},
#  {'model': 'meta-llama/Llama-2-7b-chat-hf',
#   'url': 'https://huggingface.co/meta-llama/Llama-2-7b-chat-hf',
#   'license': 'Llama 2 Community License',
#   'commercial_use': 'Conditional',
#   'restrictions': ['MAU cap (moins de 700M utilisateurs actifs mensuels)',
#    "Attribution et application de la politique d'utilisation responsable"]}]

# %% [markdown]
# ### Checklist template (fill and keep in markdown)
# - [x] **Model 1: mistralai/Mistral-7B-Instruct-v0.3**
#   - Type of license:
#     - [x] Apache 2.0
#   - Commercial use allowed:
#     - [x] Yes
#   - Restrictions:
#     - [x] Attribution (via la licence Apache 2.0)
#     - [ ] Aucune autre restriction majeure spécifique au modèle
# - [x] **Model 2: meta-llama/Llama-2-7b-chat-hf**
#   - Type of license:
#     - [x] Llama 2 Community License
#   - Commercial use allowed:
#     - [x] Conditional
#   - Restrictions:
#     - [x] Restriction #1: Limite d'utilisateurs actifs mensuels (MAU) inférieure à 700 millions
#     - [x] Restriction #2: Attribution et respect de la politique d'utilisation responsable

# %% [markdown]
# ## Exercise 3: LLM Matchmaker Challenge
# **Use:** CPU inference, low-end laptops, multilingual needs; HF filters; size <=7B; benchmarks (BoolQ, GSM8K, FLORES-200).
#
# **Step-by-step**
# 1) Analyze team needs (LegalTech CPU logic; EdTech math/logic low-end; Global NGO multilingual >=5 langs).
# 2) Apply HF filters (cpu/quantized, logic/math/multilingual tags, size <=7B).
# 3) List 3?5 candidates per team with params/arch/quantization/benchmarks.
# 4) Compare top 2 per team and pick the best model with justification.
# 5) Fill the table with your picks.
#
# **Deliverables:** filter summary + filled picks table.

# %%
filters_by_team = {
    "LegalTech": ["text-generation", "cpu", "gguf", "logic/boolq", "<=7B", "rapide"],
    "EdTech": ["math/gsm8k tag", "cpu/quantized", "<=7B (préférer <=4B)", "raisonnement"],
    "Global NGO": ["multilingual tag", "cpu/gguf", "<=7B", "couverture linguistique étendue"],
}
filters_by_team
# Out:
# {'LegalTech': ['text-generation',
#   'cpu',
#   'gguf',
#   'logic/boolq',
#   '<=7B',
#   'rapide'],
#  'EdTech': ['math/gsm8k tag',
#   'cpu/quantized',
#   '<=7B (préférer <=4B)',
#   'raisonnement'],
#  'Global NGO': ['multilingual tag',
#   'cpu/gguf',
#   '<=7B',
#   'couverture linguistique étendue']}

# %%
candidates_by_team = {
    "LegalTech": [
        {"model": "Mistral-7B-Instruct-v0.2 (GGUF)", "params_b": "7", "arch": "Mistral", "optimization": "GGUF-Q4_K_M", "benchmarks": "BoolQ élevé, vitesse CPU"},
        {"model": "zephyr-7b-beta (GGUF)", "params_b": "7", "arch": "Mistral", "optimization": "GGUF-Q4_K_M", "benchmarks": "BoolQ décent, adapté au chat"},
    ],
    "EdTech": [
        {"model": "microsoft/Phi-2 (GGUF)", "params_b": "2.7", "arch": "Transformer", "optimization": "GGUF-Q4_K_M", "benchmarks": "GSM8K fort, raisonnement"},
        {"model": "Qwen/Qwen1.5-1.8B-Chat-GGUF", "params_b": "1.8", "arch": "Transformer", "optimization": "GGUF-Q4_K_M", "benchmarks": "Bon pour la logique/le chat"},
    ],
    "Global NGO": [
        {"model": "google/gemma-2b-it (GGUF)", "params_b": "2", "arch": "Gemma", "optimization": "GGUF-Q4_K_M", "benchmarks": "FLORES-200 (multilingue), performance rapide"},
        {"model": "mistralai/Mistral-7B-Instruct-v0.2 (GGUF)", "params_b": "7", "arch": "Mistral", "optimization": "GGUF-Q4_K_M", "benchmarks": "FLORES-200 (multilingue décent), généraliste"},
    ],
}
candidates_by_team
# Out:
# {'LegalTech': [{'model': 'Mistral-7B-Instruct-v0.2 (GGUF)',
#    'params_b': '7',
#    'arch': 'Mistral',
#    'optimization': 'GGUF-Q4_K_M',
#    'benchmarks': 'BoolQ élevé, vitesse CPU'},
#   {'model': 'zephyr-7b-beta (GGUF)',
#    'params_b': '7',
#    'arch': 'Mistral',
#    'optimization': 'GGUF-Q4_K_M',
#    'benchmarks': 'BoolQ décent, adapté au chat'}],
#  'EdTech': [{'model': 'microsoft/Phi-2 (GGUF)',
#    'params_b': '2.7',
#    'arch': 'Transformer',
#    'optimization': 'GGUF-Q4_K_M',
#    'benchmarks': 'GSM8K fort, raisonnement'},
#   {'model': 'Qwen/Qwen1.5-1.8B-Chat-GGUF',
#    'params_b': '1.8',
#    'arch': 'Transformer',
#    'optimization': 'GGUF-Q4_K_M',
#    'benchmarks': 'Bon pour la logique/le chat'}],
#  'Global NGO': [{'model': 'google/gemma-2b-it (GGUF)',
#    'params_b': '2',
#    'arch': 'Gemma',
#    'optimization': 'GGUF-Q4_K_M',
#    'benchmarks': 'FLORES-200 (multilingue), performance rapide'},
# ...

# %%
matchmaker_table = """| Team | Needs | Your Pick |
| --- | --- | --- |
| LegalTech | Fast model for logic-heavy chatbot on CPU | Mistral-7B-Instruct-v0.2 (GGUF) - Excellent raisonnement, très bonne performance sur CPU. |
| EdTech | Logic/math-focused LLM on low-end laptops | microsoft/Phi-2 (GGUF) - Très compact (2.7B), solide sur la logique et les maths, idéal pour les appareils de faible puissance. |
| Global NGO | Model that speaks 5+ languages well | google/gemma-2b-it (GGUF) - Petit, rapide et bonne performance multilingue pour sa taille. |"""
print(matchmaker_table)
# Out:
# | Team | Needs | Your Pick |
# | --- | --- | --- |
# | LegalTech | Fast model for logic-heavy chatbot on CPU | Mistral-7B-Instruct-v0.2 (GGUF) - Excellent raisonnement, très bonne performance sur CPU. |
# | EdTech | Logic/math-focused LLM on low-end laptops | microsoft/Phi-2 (GGUF) - Très compact (2.7B), solide sur la logique et les maths, idéal pour les appareils de faible puissance. |
# | Global NGO | Model that speaks 5+ languages well | google/gemma-2b-it (GGUF) - Petit, rapide et bonne performance multilingue pour sa taille. |

# %% [markdown]
# ## Exercise 4: Local Readiness Audit
# **Use:** RAM/disk/OS; llama.cpp requirements (AVX/SSE, cmake/make/gcc/clang); quantized formats (GGUF).
#
# **Step-by-step**
# 1) Gather system specs (RAM, free disk, OS type/version).
# 2) Fill the audit table and mark ?/?.
# 3) Check llama.cpp readiness (instruction sets, compilers, build tools).
# 4) Identify upgrade needs for each ?.
#
# **Deliverables:** filled table + upgrade summary.

# %%
system_specs = {
    "ram_gb": "16 GB",
    "free_disk_gb": "80 GB",
    "os": "Ubuntu 22.04 (WSL2)",
}
system_specs
# Out:
# {'ram_gb': '16 GB', 'free_disk_gb': '80 GB', 'os': 'Ubuntu 22.04 (WSL2)'}

# %%
readiness_table = """| Requirement | Your System Specs | Meets Requirement? |
| --- | --- | --- |
| RAM (>= 16 GB) | 16 GB | Oui / Oui |
| Free Disk Space (>= 40 GB) | 80 GB | Oui / Oui |
| OS (Linux/WSL2) | Ubuntu 22.04 (WSL2) | Oui / Oui |"""
print(readiness_table)
# Out:
# | Requirement | Your System Specs | Meets Requirement? |
# | --- | --- | --- |
# | RAM (>= 16 GB) | 16 GB | Oui / Oui |
# | Free Disk Space (>= 40 GB) | 80 GB | Oui / Oui |
# | OS (Linux/WSL2) | Ubuntu 22.04 (WSL2) | Oui / Oui |

# %%
llama_cpp_readiness = {
    "cpu_instruction_support": "AVX2 (commun sur les CPUs modernes)",
    "tooling": ["cmake (installé via apt)", "gcc/clang (installé via apt)"],
    "other_requirements": "Python 3.x, pip, bibliothèques Python (ex: ctransformers)",
}
llama_cpp_readiness
# Out:
# {'cpu_instruction_support': 'AVX2 (commun sur les CPUs modernes)',
#  'tooling': ['cmake (installé via apt)', 'gcc/clang (installé via apt)'],
#  'other_requirements': 'Python 3.x, pip, bibliothèques Python (ex: ctransformers)'}

# %%
upgrade_actions = [
    "Mettre à jour le système d'exploitation pour une compatibilité optimale avec WSL2 (si ce n'est pas déjà fait).",
    "S'assurer que les dépendances de construction (cmake, gcc) sont installées et à jour.",
    "Vérifier la disponibilité des pilotes GPU (si applicable) pour une accélération potentielle.",
]
upgrade_actions
# Out:
# ["Mettre à jour le système d'exploitation pour une compatibilité optimale avec WSL2 (si ce n'est pas déjà fait).",
#  "S'assurer que les dépendances de construction (cmake, gcc) sont installées et à jour.",
#  'Vérifier la disponibilité des pilotes GPU (si applicable) pour une accélération potentielle.']

# %% [markdown]
# ## Exercise 5: Benchmark-Based Model Explorer
# **Use:** Open LLM Leaderboard; HellaSwag and MMLU scores; license types; use-case mapping.
#
# **Step-by-step**
# 1) Pick three models from the leaderboard with different strengths (high HellaSwag, high MMLU, balanced).
# 2) Record HellaSwag, MMLU, license, and ideal use case.
# 3) Fill the comparison table.
# 4) Optional: 1?2 sentence reflection on why benchmarks matter.
# 5) Quiz-style reflection: write 3 short Q&A items about choosing models for different constraints.
#
# **Deliverables:** model list + filled table + quiz-style reflection (+ optional reflection paragraph).

# %%
leaderboard_models = [
    {"model": "Mistral-7B-Instruct-v0.2", "url": "https://huggingface.co/mistralai/Mistral-7B-Instruct-v0.2", "hellaswag": "83.4", "mmlu": "62.5", "license": "Apache 2.0", "ideal_use_case": "Raisonnement général, chatbots"},
    {"model": "Llama-2-7b-chat-hf", "url": "https://huggingface.co/meta-llama/Llama-2-7b-chat-hf", "hellaswag": "78.9", "mmlu": "54.3", "license": "Llama 2 Community License", "ideal_use_case": "Discussion conversationnelle, applications d'entreprise (sous conditions)"},
    {"model": "google/gemma-7b-it", "url": "https://huggingface.co/google/gemma-7b-it", "hellaswag": "81.1", "mmlu": "64.3", "license": "Gemma License", "ideal_use_case": "Équilibré, bonne performance générale, inférence rapide"},
]
leaderboard_models
# Out:
# [{'model': 'Mistral-7B-Instruct-v0.2',
#   'url': 'https://huggingface.co/mistralai/Mistral-7B-Instruct-v0.2',
#   'hellaswag': '83.4',
#   'mmlu': '62.5',
#   'license': 'Apache 2.0',
#   'ideal_use_case': 'Raisonnement général, chatbots'},
#  {'model': 'Llama-2-7b-chat-hf',
#   'url': 'https://huggingface.co/meta-llama/Llama-2-7b-chat-hf',
#   'hellaswag': '78.9',
#   'mmlu': '54.3',
#   'license': 'Llama 2 Community License',
#   'ideal_use_case': "Discussion conversationnelle, applications d'entreprise (sous conditions)"},
#  {'model': 'google/gemma-7b-it',
#   'url': 'https://huggingface.co/google/gemma-7b-it',
#   'hellaswag': '81.1',
#   'mmlu': '64.3',
#   'license': 'Gemma License',
#   'ideal_use_case': 'Équilibré, bonne performance générale, inférence rapide'}]

# %%
benchmark_table = """| Model Name | HellaSwag Score | MMLU Score | License Type | Ideal Use Case |
| --- | --- | --- | --- | --- |
| Mistral-7B-Instruct-v0.2 | 83.4 | 62.5 | Apache 2.0 | Raisonnement général, chatbots |
| Llama-2-7b-chat-hf | 78.9 | 54.3 | Llama 2 Community License | Discussion conversationnelle, applications d'entreprise |
| google/gemma-7b-it | 81.1 | 64.3 | Gemma License | Équilibré, bonne performance générale, inférence rapide |"""
print(benchmark_table)
# Out:
# | Model Name | HellaSwag Score | MMLU Score | License Type | Ideal Use Case |
# | --- | --- | --- | --- | --- |
# | Mistral-7B-Instruct-v0.2 | 83.4 | 62.5 | Apache 2.0 | Raisonnement général, chatbots |
# | Llama-2-7b-chat-hf | 78.9 | 54.3 | Llama 2 Community License | Discussion conversationnelle, applications d'entreprise |
# | google/gemma-7b-it | 81.1 | 64.3 | Gemma License | Équilibré, bonne performance générale, inférence rapide |

# %% [markdown]
# ### Optional reflection
# Les benchmarks sont cruciaux car ils fournissent une évaluation objective et quantifiable de la performance des modèles sur diverses tâches. Ils permettent de dépasser le "hype" et de choisir un modèle dont les capacités sont avérées, garantissant qu'il répond aux exigences spécifiques d'une application ou d'un cas d'utilisation, évitant ainsi les coûteuses erreurs de sélection.

# %%
quiz_reflection = [
    {"question": "Pourquoi un score MMLU élevé est-il important pour un assistant de recherche académique ?", "answer": "Un score MMLU élevé indique une connaissance générale étendue et des capacités de raisonnement multi-tâches, essentielles pour synthétiser des informations académiques diverses."},
    {"question": "Quel benchmark est le plus pertinent pour un chatbot de service client qui doit comprendre les requêtes complexes des utilisateurs ?", "answer": "Le benchmark HellaSwag est très pertinent car il évalue la capacité de raisonnement de bon sens du modèle, cruciale pour interpréter et répondre de manière appropriée aux intentions variées des clients."},
    {"question": "Envisageriez-vous un modèle avec un score HellaSwag légèrement inférieur si sa licence permettait une utilisation commerciale illimitée, par rapport à un modèle avec un score plus élevé mais des restrictions de licence ?", "answer": "Oui, si l'utilisation commerciale illimitée est une exigence critique, les implications de la licence peuvent l'emporter sur une légère différence de performance de benchmark, car un modèle non utilisable commercialement est sans valeur pour une entreprise."},
]
quiz_reflection
# Out:
# [{'question': 'Pourquoi un score MMLU élevé est-il important pour un assistant de recherche académique ?',
#   'answer': 'Un score MMLU élevé indique une connaissance générale étendue et des capacités de raisonnement multi-tâches, essentielles pour synthétiser des informations académiques diverses.'},
#  {'question': 'Quel benchmark est le plus pertinent pour un chatbot de service client qui doit comprendre les requêtes complexes des utilisateurs ?',
#   'answer': 'Le benchmark HellaSwag est très pertinent car il évalue la capacité de raisonnement de bon sens du modèle, cruciale pour interpréter et répondre de manière appropriée aux intentions variées des clients.'},
#  {'question': 'Envisageriez-vous un modèle avec un score HellaSwag légèrement inférieur si sa licence permettait une utilisation commerciale illimitée, par rapport à un modèle avec un score plus élevé mais des restrictions de licence ?',
# ...

# %% [markdown]
# ## Exercise 6: Cloud vs. Local Deployment Plan
# **Use:** local vs. cloud cost/latency/scalability/security/maintenance; optional Colab timing.
#
# **Step-by-step**
# 1) Draft 5 bullets pairing local vs. cloud pros/cons.
# 2) Optional: run a 7B model on Colab; note model and response time.
# 3) Summarize Colab observation if you ran it.
#
# **Deliverables:** 5 bullets; optional Colab report (model + time).

# %%
pros_and_cons = [
    "Local: Coût initial élevé pour le matériel, mais pas de coûts récurrents basés sur l'utilisation.",
    "Cloud: Faible coût initial, mais coûts variables qui peuvent augmenter avec l'utilisation et la taille du modèle.",
    "Local: Latence plus faible car les données et le traitement restent sur l'appareil.",
    "Cloud: Scalabilité illimitée pour gérer des pics de charge, mais peut introduire de la latence réseau.",
    "Local: Contrôle total sur la sécurité des données, idéal pour les informations sensibles (si bien sécurisé).",
    "Cloud: La sécurité dépend du fournisseur de cloud, avec des responsabilités partagées.",
    "Local: Maintenance et mises à niveau du matériel sous la responsabilité de l'utilisateur.",
    "Cloud: Le fournisseur gère la maintenance de l'infrastructure, réduisant la charge opérationnelle.",
    "Local: Déploiement plus complexe et gestion des dépendances environnementales.",
    "Cloud: Déploiement simplifié grâce à des services managés et des environnements préconfigurés."
]
pros_and_cons
# Out:
# ["Local: Coût initial élevé pour le matériel, mais pas de coûts récurrents basés sur l'utilisation.",
#  "Cloud: Faible coût initial, mais coûts variables qui peuvent augmenter avec l'utilisation et la taille du modèle.",
#  "Local: Latence plus faible car les données et le traitement restent sur l'appareil.",
#  'Cloud: Scalabilité illimitée pour gérer des pics de charge, mais peut introduire de la latence réseau.',
#  'Local: Contrôle total sur la sécurité des données, idéal pour les informations sensibles (si bien sécurisé).',
#  'Cloud: La sécurité dépend du fournisseur de cloud, avec des responsabilités partagées.',
#  "Local: Maintenance et mises à niveau du matériel sous la responsabilité de l'utilisateur.",
#  "Cloud: Le fournisseur gère la maintenance de l'infrastructure, réduisant la charge opérationnelle.",
#  'Local: Déploiement plus complexe et gestion des dépendances environnementales.',
# ...

# %%
colab_run = {
    "model_tested": "TODO",
    "response_time_seconds": "TODO",
    "notes": "TODO",
}
colab_run
# Out:
# {'model_tested': 'TODO', 'response_time_seconds': 'TODO', 'notes': 'TODO'}
